# %% [markdown]
# Edit the ingredients_facts file to place into the vector db

# %%
import pandas as pd 

df = pd.read_csv('Data/ingredients_facts.csv')
df.head(10)
# Out:
# C:\Users\Jason\AppData\Local\Temp\ipykernel_3184\2413653658.py:3: DtypeWarning: Columns (0,3,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Data/ingredients_facts.csv')
#   nutrient_id                                         Unnamed: 1     1003  \
# 0        name                                                NaN  Protein
# 1      fdc_id                                        description      NaN
# 2      167513  Pillsbury, Cinnamon Rolls with Icing, refriger...   4.34 g
# 3      167521     Pie Crust, Cookie-type, Chocolate, Ready Crust   6.08 g
# 4      167524     Waffles, chocolate chip, frozen, ready-to-heat    5.8 g
# 5      167526  Bread, salvadoran sweet cheese (quesadilla sal...   7.12 g
# 6      167528       Pastry, Pastelitos de Guava (guava pastries)   5.48 g
# 7      167532                                 Bread, white wheat  10.66 g
# 8      167533                                      Bagels, wheat   10.2 g
# ...

# %%
df.drop(columns = 'nutrient_id', inplace = True)
df.head(10)
# Out:
#                                           Unnamed: 1     1003    1007  \
# 0                                                NaN  Protein     Ash
# 1                                        description      NaN     NaN
# 2  Pillsbury, Cinnamon Rolls with Icing, refriger...   4.34 g  3.08 g
# 3     Pie Crust, Cookie-type, Chocolate, Ready Crust   6.08 g  2.03 g
# 4     Waffles, chocolate chip, frozen, ready-to-heat    5.8 g   2.8 g
# 5  Bread, salvadoran sweet cheese (quesadilla sal...   7.12 g  2.44 g
# 6       Pastry, Pastelitos de Guava (guava pastries)   5.48 g  0.99 g
# 7                                 Bread, white wheat  10.66 g  3.69 g
# 8                                      Bagels, wheat   10.2 g  1.82 g
# 9  Cream puff, eclair, custard or cream filled, iced   4.41 g   1.0 g
#
#                    1079      1089        1093         1253  \
# 0  Fiber, total dietary  Iron, Fe  Sodium, Na  Cholesterol
# 1                   NaN       NaN         NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310704 entries, 0 to 310703
# Data columns (total 38 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 1  310703 non-null  object
#  1   1003        310703 non-null  object
#  2   1007        4971 non-null    object
#  3   1079        310703 non-null  object
#  4   1089        310703 non-null  object
#  5   1093        310703 non-null  object
#  6   1253        310703 non-null  object
#  7   1257        310703 non-null  object
#  8   1258        310703 non-null  object
#  9   1004        310703 non-null  object
#  10  1005        310703 non-null  object
#  11  1008        310703 non-null  object
#  12  1051        4983 non-null    object
#  13  2000        310703 non-null  object
#  14  1104        210363 non-null  object
#  15  1162        214149 non-null  object
#  16  1087        310703 non-null  object
#  17  1177        11216 non-null   object
# ...

# %%
new_header = df.iloc[0] 
df = df[1:] 
df.columns = new_header

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310703 entries, 1 to 310703
# Data columns (total 38 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   nan                                       310703 non-null  object
#  1   Protein                                   310702 non-null  object
#  2   Ash                                       4970 non-null    object
#  3   Fiber, total dietary                      310702 non-null  object
#  4   Iron, Fe                                  310702 non-null  object
#  5   Sodium, Na                                310702 non-null  object
#  6   Cholesterol                               310702 non-null  object
#  7   Fatty acids, total trans                  310702 non-null  object
#  8   Fatty acids, total saturated              310702 non-null  object
#  9   Total lipid (fat)                         310702 non-null  object
# ...

# %%
df.head(10)
# Out:
# 0                                                 NaN  Protein     Ash  \
# 1                                         description      NaN     NaN
# 2   Pillsbury, Cinnamon Rolls with Icing, refriger...   4.34 g  3.08 g
# 3      Pie Crust, Cookie-type, Chocolate, Ready Crust   6.08 g  2.03 g
# 4      Waffles, chocolate chip, frozen, ready-to-heat    5.8 g   2.8 g
# 5   Bread, salvadoran sweet cheese (quesadilla sal...   7.12 g  2.44 g
# 6        Pastry, Pastelitos de Guava (guava pastries)   5.48 g  0.99 g
# 7                                  Bread, white wheat  10.66 g  3.69 g
# 8                                       Bagels, wheat   10.2 g  1.82 g
# 9   Cream puff, eclair, custard or cream filled, iced   4.41 g   1.0 g
# 10  Tortillas, ready-to-bake or -fry, flour, shelf...   8.01 g  2.71 g
#
# 0  Fiber, total dietary Iron, Fe Sodium, Na Cholesterol  \
# 1                   NaN      NaN        NaN         NaN
# 2                 1.4 g  1.93 mg   780.0 mg      0.0 mg
# ...

# %%
df = df.drop(1)
df.head(10)
# Out:
# 0                                                 NaN  Protein     Ash  \
# 2   Pillsbury, Cinnamon Rolls with Icing, refriger...   4.34 g  3.08 g
# 3      Pie Crust, Cookie-type, Chocolate, Ready Crust   6.08 g  2.03 g
# 4      Waffles, chocolate chip, frozen, ready-to-heat    5.8 g   2.8 g
# 5   Bread, salvadoran sweet cheese (quesadilla sal...   7.12 g  2.44 g
# 6        Pastry, Pastelitos de Guava (guava pastries)   5.48 g  0.99 g
# 7                                  Bread, white wheat  10.66 g  3.69 g
# 8                                       Bagels, wheat   10.2 g  1.82 g
# 9   Cream puff, eclair, custard or cream filled, iced   4.41 g   1.0 g
# 10  Tortillas, ready-to-bake or -fry, flour, shelf...   8.01 g  2.71 g
# 11         Snacks, corn-based, extruded, chips, plain   6.17 g  2.13 g
#
# 0  Fiber, total dietary Iron, Fe Sodium, Na Cholesterol  \
# 2                 1.4 g  1.93 mg   780.0 mg      0.0 mg
# 3                 2.7 g   4.3 mg   503.0 mg      0.0 mg
# ...

# %%
df.columns.values[0] = 'Item_Name'
df.head(10)
# Out:
# 0                                           Item_Name  Protein     Ash  \
# 2   Pillsbury, Cinnamon Rolls with Icing, refriger...   4.34 g  3.08 g
# 3      Pie Crust, Cookie-type, Chocolate, Ready Crust   6.08 g  2.03 g
# 4      Waffles, chocolate chip, frozen, ready-to-heat    5.8 g   2.8 g
# 5   Bread, salvadoran sweet cheese (quesadilla sal...   7.12 g  2.44 g
# 6        Pastry, Pastelitos de Guava (guava pastries)   5.48 g  0.99 g
# 7                                  Bread, white wheat  10.66 g  3.69 g
# 8                                       Bagels, wheat   10.2 g  1.82 g
# 9   Cream puff, eclair, custard or cream filled, iced   4.41 g   1.0 g
# 10  Tortillas, ready-to-bake or -fry, flour, shelf...   8.01 g  2.71 g
# 11         Snacks, corn-based, extruded, chips, plain   6.17 g  2.13 g
#
# 0  Fiber, total dietary Iron, Fe Sodium, Na Cholesterol  \
# 2                 1.4 g  1.93 mg   780.0 mg      0.0 mg
# 3                 2.7 g   4.3 mg   503.0 mg      0.0 mg
# ...

# %%
df.to_csv('cleaned_nutrition.csv', index = False)
