# %% [markdown]
# Revised Merging with Kevin's inputs

# %%
import pandas as pd
import html
import ast

# %%
converters = {
    column: html.unescape 
    for column in ("name", "description")
} | {
    column: lambda value: tuple(map(html.unescape, ast.literal_eval(value)))
    for column in ("ingredients", "ingredients_raw_str", "search_terms", "steps")
} | {
    "tags": lambda value: frozenset(map(html.unescape, ast.literal_eval(value)))
}

df1 = pd.read_csv("Data/recipes_w_search_terms.csv", index_col = "id", converters = converters)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 494963 entries, 96313 to 9116
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 494963 non-null  object
#  1   description          494963 non-null  object
#  2   ingredients          494963 non-null  object
#  3   ingredients_raw_str  494963 non-null  object
#  4   serving_size         494963 non-null  object
#  5   servings             494963 non-null  int64
#  6   steps                494963 non-null  object
#  7   tags                 494963 non-null  object
#  8   search_terms         494963 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 37.8+ MB

# %%
df1.head(10)
# Out:
#                                          name  \
# id
# 96313             Grilled Garlic Cheese Grits
# 232037  Simple Shrimp and Andouille Jambalaya
# 41090              black-and-white bean salad
# 60656              Crock Pot Italian Zucchini
# 232047          Beef Stew With Dried Cherries
# 232050               Hot Sweet Almond Brittle
# 232076        Retro Chicken & Chips Casserole
# 232083              Asparagus  Omelette Wraps
# 79222                     Potato-Crab Chowder
# 393638           Sweet and Simple Sloppy Joes
#
#                                               description  \
# id
# 96313   We love grits, this is another good way to ser...
# 232037  Simple, easy and very tasty for when you are i...
# 41090
# 60656   This is a good recipe for weight watchers. It ...
# 232047  This is a fabulous stew that came from one of ...
# 232050  This is one of our standard holiday gift recip...
# 232076  From Cooking Light Magazine, 11/05. This is co...
# ...

# %%
df2 = pd.read_csv("Data/recipes.csv", index_col = "RecipeId", converters = converters)

# %%
df2.head(10)
# Out:
#                                                 Name  AuthorId  \
# RecipeId
# 38                 Low-Fat Berry Blue Frozen Dessert      1533
# 39                                           Biryani      1567
# 40                                     Best Lemonade      1566
# 41                    Carina's Tofu-Vegetable Kebabs      1586
# 42                                      Cabbage Soup      1538
# 43                              Best Blackbottom Pie     34879
# 44                            Warm Chicken A La King      1596
# 45        Buttermilk Pie With Gingersnap Crumb Crust      1580
# 46                           A Jad - Cucumber Pickle      1533
# 47                              Butter Pecan Cookies      1573
#
#                     AuthorName CookTime PrepTime TotalTime  \
# RecipeId
# 38                      Dancer    PT24H    PT45M  PT24H45M
# 39                    elly9812    PT25M     PT4H   PT4H25M
# 40              Stephen Little     PT5M    PT30M     PT35M
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 522517 entries, 38 to 541383
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Name                        522517 non-null  object
#  1   AuthorId                    522517 non-null  int64
#  2   AuthorName                  522517 non-null  object
#  3   CookTime                    439972 non-null  object
#  4   PrepTime                    522517 non-null  object
#  5   TotalTime                   522517 non-null  object
#  6   DatePublished               522517 non-null  object
#  7   Description                 522512 non-null  object
#  8   Images                      522516 non-null  object
#  9   RecipeCategory              521766 non-null  object
#  10  Keywords                    505280 non-null  object
#  11  RecipeIngredientQuantities  522514 non-null  object
#  12  RecipeIngredientParts       522517 non-null  object
# ...

# %%
df2 = df2[['TotalTime', 'Calories', 'FatContent', 'SaturatedFatContent', 'CholesterolContent', 'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent']]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 522517 entries, 38 to 541383
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   TotalTime            522517 non-null  object
#  1   Calories             522517 non-null  float64
#  2   FatContent           522517 non-null  float64
#  3   SaturatedFatContent  522517 non-null  float64
#  4   CholesterolContent   522517 non-null  float64
#  5   SodiumContent        522517 non-null  float64
#  6   CarbohydrateContent  522517 non-null  float64
#  7   FiberContent         522517 non-null  float64
#  8   SugarContent         522517 non-null  float64
#  9   ProteinContent       522517 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 43.9+ MB

# %%
merged_df = pd.merge(df1, df2, how = 'inner', left_on = 'id', right_on = 'RecipeId')

# %%
merged_df.head()
# Out:
#                                     name  \
# 0            Grilled Garlic Cheese Grits
# 1  Simple Shrimp and Andouille Jambalaya
# 2             black-and-white bean salad
# 3             Crock Pot Italian Zucchini
# 4          Beef Stew With Dried Cherries
#
#                                          description  \
# 0  We love grits, this is another good way to ser...
# 1  Simple, easy and very tasty for when you are i...
# 2
# 3  This is a good recipe for weight watchers. It ...
# 4  This is a fabulous stew that came from one of ...
#
#                                          ingredients  \
# 0  (water, grits, salt, cheddar cheese, garlic, o...
# 1  (onion, red bell pepper, garlic cloves, large ...
# 2  (white beans, canned black beans, tomatoes, on...
# 3  (zucchini, yellow squash, diced tomatoes, onio...
# 4  (beef stew meat, flour, salt, allspice, cinnam...
#
#                                  ingredients_raw_str serving_size  servings  \
# ...

# %%
import re
# Function to convert the TotalTime string to minutes
def convert_to_minutes(time):
    hours = 0
    minutes = 0
    
    hours_match = re.search(r'(\d+)H', time)

    if hours_match:
        hours = int(hours_match.group(1))
    
    minutes_match = re.search(r'(\d+)M', time)

    if minutes_match:
        minutes = int(minutes_match.group(1))
    
    total_minutes = hours * 60 + minutes
    return total_minutes

# %%
# Apply function
merged_df['TotalTime'] = merged_df['TotalTime'].apply(convert_to_minutes)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494949 entries, 0 to 494948
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 494949 non-null  object
#  1   description          494949 non-null  object
#  2   ingredients          494949 non-null  object
#  3   ingredients_raw_str  494949 non-null  object
#  4   serving_size         494949 non-null  object
#  5   servings             494949 non-null  int64
#  6   steps                494949 non-null  object
#  7   tags                 494949 non-null  object
#  8   search_terms         494949 non-null  object
#  9   TotalTime            494949 non-null  int64
#  10  Calories             494949 non-null  float64
#  11  FatContent           494949 non-null  float64
#  12  SaturatedFatContent  494949 non-null  float64
#  13  CholesterolContent   494949 non-null  float64
# ...

# %%
merged_df = merged_df[~merged_df.index.duplicated(keep="first")]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494949 entries, 0 to 494948
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   name                 494949 non-null  object
#  1   description          494949 non-null  object
#  2   ingredients          494949 non-null  object
#  3   ingredients_raw_str  494949 non-null  object
#  4   serving_size         494949 non-null  object
#  5   servings             494949 non-null  int64
#  6   steps                494949 non-null  object
#  7   tags                 494949 non-null  object
#  8   search_terms         494949 non-null  object
#  9   TotalTime            494949 non-null  int64
#  10  Calories             494949 non-null  float64
#  11  FatContent           494949 non-null  float64
#  12  SaturatedFatContent  494949 non-null  float64
#  13  CholesterolContent   494949 non-null  float64
# ...

# %%
merged_df = merged_df.rename(columns = {'id' : 'ID',
                            'name': 'Name',
                            'description' : 'Description',
                            'ingredients' : 'IngredientsExtracted',
                            'ingredients_raw_str' : 'IngredientsRaw',
                            'steps' : 'Instructions',
                            'servings' : 'Servings',
                            'tags' : 'Tags',
                            'search_terms' : 'SearchTerms'})

# %%
merged_df.to_csv('recipes_food_com_revised.csv', index = False)
